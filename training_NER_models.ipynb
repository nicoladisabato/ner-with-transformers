# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset-ner-training/config_xlnet.cfg
# /kaggle/input/dataset-ner-training/config.cfg
# /kaggle/input/dataset-ner-training/corpus/onto.test.spacy
# /kaggle/input/dataset-ner-training/corpus/onto.development.spacy
# /kaggle/input/dataset-ner-training/corpus/onto.train.spacy

# %%
import os

# install SpaCy v3
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
# !python -m spacy download en_core_web_trf

# %% [markdown]
# ## Training a Bert Model

# %%
# !python -m spacy train --gpu-id 0 /kaggle/input/dataset-ner-training/config_bert.cfg --output ./bert --paths.train /kaggle/input/dataset-ner-training/corpus/onto.train.spacy --paths.dev /kaggle/input/dataset-ner-training/corpus/onto.development.spacy
# Out:
# ✔ Created output directory: bert
# ℹ Saving to output directory: bert
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-03-09 15:04:34,972] [INFO] Set up nlp object from config
# [2023-03-09 15:04:34,984] [INFO] Pipeline: ['transformer', 'ner']
# [2023-03-09 15:04:34,990] [INFO] Created vocabulary
# [2023-03-09 15:04:34,992] [INFO] Finished initializing nlp object
# Downloading: 100%|███████████████████████████| 29.0/29.0 [00:00<00:00, 30.3kB/s]
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 580kB/s]
# Downloading: 100%|███████████████████████████| 208k/208k [00:00<00:00, 3.42MB/s]
# Downloading: 100%|███████████████████████████| 426k/426k [00:00<00:00, 5.09MB/s]
# Downloading: 100%|███████████████████████████| 416M/416M [00:07<00:00, 57.0MB/s]
# ...

# %% [markdown]
# ## Test results Bert

# %%
# !python -m spacy benchmark accuracy --gpu-id 0 /kaggle/working/bert/model-best /kaggle/input/dataset-ner-training/corpus/onto.test.spacy
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   86.98
# NER R   88.33
# NER F   87.65
# SPEED   13795
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# PERSON        93.07   94.33   93.69
# TIME          62.81   67.56   65.10
# GPE           93.08   94.11   93.59
# DATE          85.05   85.95   85.50
# ORG           87.79   89.46   88.62
# CARDINAL      81.46   82.19   81.82
# WORK_OF_ART   67.83   57.40   62.18
# ORDINAL       72.65   85.99   78.76
# MONEY         84.28   87.61   85.91
# LOC           76.85   77.21   77.03
# PERCENT       82.48   86.52   84.45
# NORP          91.57   93.23   92.39
# EVENT         69.88   68.24   69.05
# FAC           76.09   70.47   73.17
# LANGUAGE      76.47   59.09   66.67
# PRODUCT       65.22   66.67   65.93
# QUANTITY      70.62   73.86   72.20
# LAW           60.47   59.09   59.77

# %% [markdown]
# # Training a XLNet model

# %%
# !python -m spacy train --gpu-id 0 /kaggle/input/dataset-ner-training/config_xlnet.cfg --output ./xlnet --paths.train /kaggle/input/dataset-ner-training/corpus/onto.train.spacy --paths.dev /kaggle/input/dataset-ner-training/corpus/onto.development.spacy
# Out:
# ℹ Saving to output directory: xlnet
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-03-12 10:36:11,289] [INFO] Set up nlp object from config
# [2023-03-12 10:36:11,303] [INFO] Pipeline: ['transformer', 'ner']
# [2023-03-12 10:36:11,310] [INFO] Created vocabulary
# [2023-03-12 10:36:11,312] [INFO] Finished initializing nlp object
# Downloading: 100%|██████████████████████████████| 760/760 [00:00<00:00, 661kB/s]
# Downloading: 100%|███████████████████████████| 779k/779k [00:00<00:00, 2.13MB/s]
# Downloading: 100%|█████████████████████████| 1.32M/1.32M [00:00<00:00, 3.72MB/s]
# Downloading: 100%|███████████████████████████| 445M/445M [00:10<00:00, 44.0MB/s]
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetModel: ['lm_loss.bias', 'lm_loss.weight']
# ...

# %% [markdown]
# ## Test results XlNet

# %%
# !python -m spacy benchmark accuracy --gpu-id 0 /kaggle/working/xlnet/model-best /kaggle/input/dataset-ner-training/corpus/onto.test.spacy
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   87.51
# NER R   89.54
# NER F   88.51
# SPEED   4873
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# PERSON        92.96   94.70   93.83
# ORG           89.53   91.36   90.43
# TIME          63.33   67.56   65.38
# GPE           93.57   95.52   94.54
# DATE          83.89   89.20   86.47
# CARDINAL      81.85   80.30   81.06
# WORK_OF_ART   63.39   68.64   65.91
# MONEY         89.20   90.70   89.94
# LOC           74.32   76.74   75.51
# ORDINAL       73.42   78.74   75.99
# PERCENT       87.94   91.18   89.53
# NORP          92.93   94.24   93.58
# EVENT         65.26   72.94   68.89
# FAC           75.00   58.39   65.66
# QUANTITY      62.36   72.55   67.07
# LANGUAGE      93.33   63.64   75.68
# LAW           65.91   65.91   65.91
# PRODUCT       82.19   66.67   73.62

# %% [markdown]
# ## Training a Roberta model

# %%
# !python -m spacy train --gpu-id 0 /kaggle/input/dataset-ner-training/config.cfg --output ./roberta --paths.train /kaggle/input/dataset-ner-training/corpus/onto.train.spacy --paths.dev /kaggle/input/dataset-ner-training/corpus/onto.development.spacy
# Out:
# ✔ Created output directory: roberta
# ℹ Saving to output directory: roberta
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-03-07 21:12:06,644] [INFO] Set up nlp object from config
# [2023-03-07 21:12:06,658] [INFO] Pipeline: ['transformer', 'ner']
# [2023-03-07 21:12:06,663] [INFO] Created vocabulary
# [2023-03-07 21:12:06,664] [INFO] Finished initializing nlp object
# Downloading: 100%|██████████████████████████████| 481/481 [00:00<00:00, 524kB/s]
# Downloading: 100%|███████████████████████████| 878k/878k [00:00<00:00, 2.08MB/s]
# Downloading: 100%|███████████████████████████| 446k/446k [00:00<00:00, 1.32MB/s]
# Downloading: 100%|█████████████████████████| 1.29M/1.29M [00:00<00:00, 3.08MB/s]
# Downloading: 100%|███████████████████████████| 478M/478M [00:09<00:00, 54.8MB/s]
# ...

# %% [markdown]
# ## Test results Roberta

# %%
# !python -m spacy benchmark accuracy --gpu-id 0 /kaggle/working/roberta/model-best /kaggle/input/dataset-ner-training/corpus/onto.test.spacy
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   88.46
# NER R   88.92
# NER F   88.69
# SPEED   14697
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# PERSON        93.74   93.96   93.85
# ORG           88.34   90.86   89.58
# TIME          65.75   64.00   64.86
# GPE           93.41   96.39   94.88
# DATE          83.16   89.26   86.10
# CARDINAL      85.62   76.42   80.76
# WORK_OF_ART   68.39   62.72   65.43
# MONEY         86.94   88.17   87.55
# LOC           77.14   75.35   76.24
# PERCENT       88.29   88.73   88.51
# NORP          94.08   93.13   93.60
# EVENT         70.21   77.65   73.74
# FAC           86.24   63.09   72.87
# ORDINAL       77.83   83.09   80.37
# LANGUAGE      87.50   63.64   73.68
# QUANTITY      83.74   67.32   74.64
# LAW           72.09   70.45   71.26
# PRODUCT       86.11   68.89   76.54

# %% [markdown]
# ## Test results en_core_web_trf

# %%
# !python -m spacy benchmark accuracy --gpu-id 0 en_core_web_trf /kaggle/input/dataset-ner-training/corpus/onto.test.spacy
# Out:
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK      -
# TAG      92.39
# POS      -
# MORPH    -
# LEMMA    -
# UAS      -
# LAS      -
# NER P    70.42
# NER R    89.19
# NER F    78.70
# SENT P   89.44
# SENT R   84.58
# SENT F   86.94
# SPEED    8207
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# PERSON        59.18   93.77   72.57
# ORG           81.70   90.76   85.99
# TIME          53.41   66.22   59.13
# CARDINAL      65.80   80.40   72.37
# GPE           76.94   95.64   85.27
# DATE          75.23   88.02   81.12
# WORK_OF_ART   50.00   57.40   53.44
# MONEY         85.07   89.86   87.40
# LOC           53.48   78.60   63.65
# PERCENT       84.40   90.20   87.20
# NORP          75.53   93.54   83.57
# EVENT         59.09   76.47   66.67
# FAC           55.61   69.80   61.90
# ORDINAL       56.66   88.41   69.06
# ...

# %%
import shutil
shutil.make_archive("MODEL", 'zip', "/kaggle/working/output")
shutil.make_archive("MODEL", 'zip', "/kaggle/working/roberta")
shutil.make_archive("MODEL", 'zip', "/kaggle/working/xlnet")
# Out:
# '/kaggle/working/MODEL.zip'

# %%
from IPython.display import FileLink
FileLink(r'/kaggle/working/MODEL.zip')
